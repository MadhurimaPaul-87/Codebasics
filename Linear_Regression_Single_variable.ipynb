# %% [markdown]
# ![c1.png](data:image/png;base64,...)

# %% [markdown]
# ![c1.1.png](data:image/png;base64,...)

# %% [markdown]
# ![c1.2.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'],marker='+',color='red')
plt.xlabel('area')
plt.ylabel('price')
plt.show()

# %%
reg = LinearRegression()
reg.fit(df[['area']], df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# # **HOME WORK**

# %%
data = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/Exercise/canada_per_capita_income.csv")
data.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.scatter(data['year'],data['per capita income (US$)'],marker='o',color='red')
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.show()

# %%
regress = LinearRegression()
regress.fit(data[['year']],data['per capita income (US$)'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regress.predict([[2020]])
# Out:
# array([41288.69409442])
